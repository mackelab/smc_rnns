# %%
import numpy as np
import torch
import sys, os

sys.path.append("../")

from vi_rnn.saving import load_model
from vi_rnn.datasets import Basic_dataset
from vi_rnn.utils import orthogonalise_network

from matplotlib.colors import colorConverter as cc
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Note that models for this sweep were not include in the public repo to keep it light. Run
#
#    `train_scripts/student_teacher/test_noise.py`
#
# to obtain the models, or inquire with the authors

# %%
# load and eval models
# ----------------
# Particles = 64
# ----------------

directory = "../data_untracked/noise_tests/noise_test/"

directory_bs = os.fsencode(directory)

Stds10 = []
Stds05 = []
Stds20 = []

for file in os.listdir(directory_bs):
    filename = os.fsdecode(file)
    if filename.endswith("_vae_params.pkl"):
        model_name = filename.removesuffix("_vae_params.pkl")
        print(model_name)
        vae, params, task_params, training_params = load_model(
            directory + model_name, load_encoder=False
        )
        vae = orthogonalise_network(vae)
        if task_params["R_z"] == 0.05:
            Stds05.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.1:
            Stds10.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.2:
            Stds20.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
# Out:
# Noise_test022024_07_27_T_16_51_58
# using ReLU activation
# using uniform init
# Noise_test022024_07_28_T_22_51_28
# using ReLU activation
# using uniform init
# Noise_test0052024_07_28_T_09_31_33
# using ReLU activation
# using uniform init
# Noise_test022024_07_28_T_18_25_10
# using ReLU activation
# using uniform init
# Noise_test012024_07_28_T_14_00_48
# using ReLU activation
# using uniform init
# Noise_test012024_07_28_T_18_29_06
# using ReLU activation
# using uniform init
# Noise_test022024_07_28_T_13_58_40
# using ReLU activation
# using uniform init
# Noise_test012024_07_27_T_16_52_04
# using ReLU activation
# using uniform init
# Noise_test012024_07_28_T_22_58_37
# using ReLU activation
# using uniform init
# Noise_test012024_07_28_T_09_32_06
# using ReLU activation
# using uniform init
# Noise_test0052024_07_27_T_16_52_13
# using ReLU activation
# using uniform init
# Noise_test0052024_07_28_T_22_55_10
# using ReLU activation
# using uniform init
# Noise_test022024_07_28_T_09_32_42
# using ReLU activation
# using uniform init
# Noise_test0052024_07_28_T_18_26_55
# using ReLU activation
# using uniform init
# Noise_test0052024_07_28_T_13_58_49
# using ReLU activation
# using uniform init

# %%
from vi_rnn.initialize_parameterize import full_cov_embed

# %%
torch.sqrt(full_cov_embed(vae.rnn.R_z))
# Out:
# tensor([[0.0547, 0.0134],
#         [0.0134, 0.0548]], grad_fn=<SqrtBackward0>)

# %%
# load and eval models

# ----------------
# Particles = 10
# ----------------

directory = "../data_untracked/noise_tests/noise_test10/"

directory_bs = os.fsencode(directory)

Stds1010 = []
Stds0510 = []
Stds2010 = []

for file in os.listdir(directory_bs):
    filename = os.fsdecode(file)
    if filename.endswith("_vae_params.pkl"):
        model_name = filename.removesuffix("_vae_params.pkl")
        print(model_name)
        vae, params, task_params, training_params = load_model(
            directory + model_name, load_encoder=False
        )
        vae = orthogonalise_network(vae)

        if task_params["R_z"] == 0.05:
            Stds0510.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.1:
            Stds1010.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.2:
            Stds2010.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
# Out:
# Noise_test012024_08_01_T_03_43_21
# using ReLU activation
# using uniform init
# Noise_test0052024_08_01_T_23_20_41
# using ReLU activation
# using uniform init
# Noise_test022024_08_01_T_03_41_26
# using ReLU activation
# using uniform init
# Noise_test0052024_08_01_T_03_39_45
# using ReLU activation
# using uniform init
# Noise_test012024_08_01_T_23_29_46
# using ReLU activation
# using uniform init
# Noise_test022024_08_01_T_23_29_22
# using ReLU activation
# using uniform init
# Noise_test022024_08_01_T_12_33_50
# using ReLU activation
# using uniform init
# Noise_test0052024_08_02_T_08_13_24
# using ReLU activation
# using uniform init
# Noise_test0052024_08_01_T_12_29_20
# using ReLU activation
# using uniform init
# Noise_test022024_07_31_T_18_52_23
# using ReLU activation
# using uniform init
# Noise_test012024_07_31_T_18_55_36
# using ReLU activation
# using uniform init
# Noise_test0052024_07_31_T_18_51_16
# using ReLU activation
# using uniform init
# Noise_test012024_08_01_T_12_35_19
# using ReLU activation
# using uniform init
# Noise_test022024_08_02_T_08_23_17
# using ReLU activation
# using uniform init
# Noise_test012024_08_02_T_08_22_47
# using ReLU activation
# using uniform init

# %%
# load and eval models

# ----------------
# Particles = 1
# ----------------

directory = "../data_untracked/noise_tests/noise_test1/"

directory_bs = os.fsencode(directory)

Stds101 = []
Stds051 = []
Stds201 = []
i = 0
for file in os.listdir(directory_bs):
    filename = os.fsdecode(file)
    if filename.endswith("_vae_params.pkl"):
        i += 1
        print(i)
        model_name = filename.removesuffix("_vae_params.pkl")
        print(model_name)
        vae, params, task_params, training_params = load_model(
            directory + model_name, load_encoder=False
        )
        vae = orthogonalise_network(vae)

        if task_params["R_z"] == 0.05:
            Stds051.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.1:
            Stds101.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.2:
            Stds201.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
# Out:
# 1
# Noise_test012024_08_01_T_09_05_05
# using ReLU activation
# using uniform init
# 2
# Noise_test012024_08_01_T_15_06_24
# using ReLU activation
# using uniform init
# 3
# Noise_test0052024_08_01_T_12_10_08
# using ReLU activation
# using uniform init
# 4
# Noise_test012024_08_01_T_12_09_12
# using ReLU activation
# using uniform init
# 5
# Noise_test022024_08_03_T_03_00_53
# using ReLU activation
# using uniform init
# 6
# Noise_test012024_08_01_T_09_04_55
# using ReLU activation
# using uniform init
# 7
# Noise_test022024_08_02_T_19_05_02
# using ReLU activation
# using uniform init
# 8
# Noise_test0052024_08_01_T_15_07_32
# using ReLU activation
# using uniform init
# 9
# Noise_test0052024_08_01_T_17_44_58
# using ReLU activation
# using uniform init
# 10
# Noise_test022024_08_02_T_18_51_49
# using ReLU activation
# using uniform init
# 11
# Noise_test022024_08_03_T_02_44_00
# using ReLU activation
# using uniform init
# 12
# Noise_test022024_08_03_T_09_58_51
# using ReLU activation
# using uniform init
# 13
# Noise_test0052024_08_01_T_09_05_18
# using ReLU activation
# using uniform init
# 14
# Noise_test012024_08_01_T_12_10_37
# using ReLU activation
# using uniform init
# 15
# Noise_test0052024_08_01_T_20_20_01
# using ReLU activation
# using uniform init

# %%
# load and eval models

# ----------------
# Particles = 64 + Bootstrap Sampling
# ----------------

directory = "../data_untracked/noise_tests/noise_test_bs/"

directory_bs = os.fsencode(directory)

Stds10bs = []
Stds05bs = []
Stds20bs = []
i = 0
for file in os.listdir(directory_bs):
    filename = os.fsdecode(file)
    if filename.endswith("_vae_params.pkl"):
        i += 1
        print(i)
        model_name = filename.removesuffix("_vae_params.pkl")
        print(model_name)
        print(training_params["resample"])
        vae, params, task_params, training_params = load_model(
            directory + model_name, load_encoder=False
        )
        vae = orthogonalise_network(vae)
        print(training_params["k"], training_params["loss_f"])
        print(params["rnn_params"]["shared_tau"])
        if task_params["R_z"] == 0.05:
            Stds05bs.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.1:
            Stds10bs.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
        elif task_params["R_z"] == 0.2:
            Stds20bs.append(vae.rnn.std_embed_z(vae.rnn.R_z).detach().numpy())
# Out:
# 1
# Noise_test_BS0052024_08_04_T_01_29_04
# none
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 2
# Noise_test_BS022024_08_04_T_16_20_38
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 3
# Noise_test_BS012024_08_04_T_01_28_55
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 4
# Noise_test_BS0052024_08_04_T_16_20_30
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 5
# Noise_test_BS012024_08_05_T_10_18_53
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 6
# Noise_test_BS012024_08_04_T_11_23_41
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 7
# Noise_test_BS022024_08_04_T_01_28_41
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 8
# Noise_test_BS022024_08_04_T_11_23_05
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 9
# Noise_test_BS012024_08_04_T_06_26_25
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 10
# Noise_test_BS022024_08_04_T_06_24_55
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 11
# Noise_test_BS022024_08_03_T_20_32_44
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 12
# Noise_test_BS012024_08_03_T_20_32_22
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 13
# Noise_test_BS0052024_08_03_T_20_32_10
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 14
# Noise_test_BS0052024_08_04_T_11_21_27
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7
# 15
# Noise_test_BS0052024_08_04_T_06_25_38
# systematic
# using ReLU activation
# using uniform init
# 64 bs_VGTF
# 0.7

# %%
n = 5

# %%
dat05 = np.array(Stds05)[:n].flatten()
dat10 = np.array(Stds10)[:n].flatten()
dat20 = np.array(Stds20)[:n].flatten()
dat0510 = np.array(Stds0510)[:n].flatten()
dat1010 = np.array(Stds1010)[:n].flatten()
dat2010 = np.array(Stds2010)[:n].flatten()
dat051 = np.array(Stds051)[:n].flatten()
dat101 = np.array(Stds101)[:n].flatten()
dat201 = np.array(Stds201)[:n].flatten()
dat05bs = np.array(Stds05bs)[:n].flatten()
dat10bs = np.array(Stds10bs)[:n].flatten()
dat20bs = np.array(Stds20bs)[:n].flatten()

# %%
# Plot box plots
alpha = 0.5
plt_colors = ["teal"] * 6
fig, ax = plt.subplots(1, 1, figsize=(2, 1), dpi=300)

c1 = "darkturquoise"
c2 = "teal"
c3 = "darkslategray"
c4 = "slateblue"
pos_64 = [0, 4, 8]
pos_10 = [1, 5, 9]
pos_1 = [2, 6, 10]
pos_bs = [3, 7, 11]

sep = 0.5
pos_64[1] += sep
pos_10[1] += sep
pos_1[1] += sep
pos_bs[1] += sep
pos_64[2] += 2 * sep
pos_10[2] += 2 * sep
pos_1[2] += 2 * sep
pos_bs[2] += 2 * sep


ax.boxplot(
    [dat05, dat10, dat20],
    positions=pos_64,
    widths=0.6,
    patch_artist=True,
    boxprops=dict(facecolor=cc.to_rgba(c1, alpha=alpha), color=c1),
    capprops=dict(color=c1),
    whiskerprops=dict(color=c1),
    medianprops=dict(color=c1),
    flierprops={
        "marker": "o",
        "markersize": 1,
        "markerfacecolor": c1,
        "markeredgecolor": c1,
    },
    label="k=64",
    zorder=10,
)

ax.boxplot(
    [dat0510, dat1010, dat2010],
    positions=pos_10,
    widths=0.6,
    patch_artist=True,
    boxprops=dict(facecolor=cc.to_rgba(c2, alpha=alpha), color=c2),
    capprops=dict(color=c2),
    whiskerprops=dict(color=c2),
    medianprops=dict(color=c2),
    flierprops={
        "marker": "o",
        "markersize": 1,
        "markerfacecolor": c2,
        "markeredgecolor": c2,
    },
    label="k=10",
    zorder=5,
)

ax.boxplot(
    [dat051, dat101, dat201],
    positions=pos_1,
    widths=0.6,
    patch_artist=True,
    boxprops=dict(facecolor=cc.to_rgba(c3, alpha=alpha), color=c3),
    capprops=dict(color=c3),
    whiskerprops=dict(color=c3),
    medianprops=dict(color=c3),
    flierprops={
        "marker": "o",
        "markersize": 1,
        "markerfacecolor": c3,
        "markeredgecolor": c3,
    },
    label="k=1",
)

ax.boxplot(
    [dat05bs, dat10bs, dat20bs],
    positions=pos_bs,
    widths=0.6,
    patch_artist=True,
    boxprops=dict(facecolor=cc.to_rgba(c4, alpha=alpha), color=c4),
    capprops=dict(color=c4),
    whiskerprops=dict(color=c4),
    medianprops=dict(color=c4),
    flierprops={
        "marker": "o",
        "markersize": 1,
        "markerfacecolor": c4,
        "markeredgecolor": c4,
    },
    label="Bootstrap (k=64)",
)

# labels
ax.set_xticks([])
#ax.set_ylim(0, 0.3)
ax.set_yticks([0.05, 0.1, 0.2])
ax.set_yticklabels([".05", ".1", ".2"])
ax.set_ylabel(r"student $\sigma$")
ax.spines[["bottom"]].set_visible(False)

# teacher sigma
lw = 2
ct = "violet"
lb = 1
dashes = (2, 0.5)
ax.plot(
    [1.5 - lw, 1.5 + lw],
    [0.05, 0.05],
    color=ct,
    zorder=-10,
    label=r"teacher $\sigma$",
    lw=lb,
    ls="--",
    dashes=dashes,
)
ax.plot(
    [5.5 + sep - lw, 5.5 + sep + lw],
    [0.1, 0.1],
    color=ct,
    zorder=-10,
    lw=lb,
    ls="--",
    dashes=dashes,
)
ax.plot(
    [9.5 + sep * 2 - lw, 9.5 + sep * 2 + lw],
    [0.2, 0.2],
    color=ct,
    zorder=-10,
    lw=lb,
    ls="--",
    dashes=dashes,
)

# legend
legend = ax.legend(
    loc="upper right",
    bbox_to_anchor=(1.65, 1),
    fontsize=6,
    handlelength=0.55,
    handleheight=0.5,
)
legend_colors = [c1, c2, c3, c4, ct]
for text, color in zip(legend.get_texts(), legend_colors):
    text.set_color(color)

plt.savefig("../figures/noise_comps.svg")
plt.savefig("../figures/noise_comps.png")
